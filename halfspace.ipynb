# %%
import timeit
import torch
from tqdm import tqdm
import numpy as np
import logging
from hype.sn import Embedding 
from hype import train
from hype.graph import load_edge_list, eval_reconstruction
from hype.rsgd import RiemannianSGD
from hype.Poincare import PoincareManifold
from hype.Halfspace import HalfspaceManifold
import sys
import json
import torch.multiprocessing as mp
from hype.graph_dataset import BatchedDataset

device = torch.device('cpu')
torch.set_default_tensor_type('torch.DoubleTensor')
#torch.set_default_tensor_type('torch.HalfTensor')
torch.manual_seed(42)
np.random.seed(42)

# %%
## parameters; these are global in the notebook!
opt_maxnorm = 500000; opt_debug = False; opt_epochs = 1000; 
opt_dim = 2; opt_com_n = 1;
opt_negs = 50; opt_batchsize = 10; opt_eval_each = 20;
opt_sparse = True; opt_ndproc = 4;  opt_burnin = 20;
opt_dampening = 0.75; opt_neg_multiplier = 1.0; 
opt_burnin_multiplier = 0.01; opt_lr = 0.3;
# opt_manifold = "Poincare"
opt_manifold = "Halfspace"
#######################################

# %%
MANIFOLDS = {
    'Poincare': PoincareManifold,
    'Halfspace': HalfspaceManifold,
}

# %% [markdown]
# ### Initializing logging and data loading

# %%
log_level = logging.DEBUG if opt_debug else logging.INFO
log = logging.getLogger('MCF')
logging.basicConfig(level=log_level, format='%(message)s', stream=sys.stdout)
log.info('Using edge list dataloader')
idx, objects, weights = load_edge_list("wordnet/mammal_closure.csv", False)
# Out:
# Using edge list dataloader

# %% [markdown]
# ### Initializing model

# %%
def init_model(manifold, idx, objects, weights, sparse=True):
    conf = []
    model_name = '%s_dim%d%com_n'
    mname = model_name % (opt_manifold, opt_dim, opt_com_n)
    data = BatchedDataset(idx, objects, weights, opt_negs, opt_batchsize,
        opt_ndproc, opt_burnin > 0, opt_dampening)
    model = Embedding(len(data.objects), opt_dim, manifold, sparse=sparse, com_n=opt_com_n)
    data.objects = objects
    return model, data, mname, conf

def adj_matrix(data):
  adj = {}
  for inputs, _ in data:
    for row in inputs:
        x = row[0].item()
        y = row[1].item()
        if x in adj:
            adj[x].add(y)
        else:
            adj[x] = {y}
  return adj

# %% [markdown]
# ### Training

# %%
def data_loader_lr(data, epoch, progress = False):
  data.burnin = False 
  lr = opt_lr
  if epoch < opt_burnin:
    data.burnin = True
    lr = opt_lr * train._lr_multiplier
  loader_iter = tqdm(data) if progress else data
  return loader_iter, lr

# %%
def train(device, model, data, optimizer, progress=False):  
  epoch_loss = torch.Tensor(len(data))
  LOSS = np.zeros(opt_epochs)
  
  for epoch in range(opt_epochs):
    largest_weight_emb = round(torch.abs(model.lt.weight.data).max().item(), 6)
    print(largest_weight_emb, "is the largest absolute weight in the embedding")
    
    epoch_loss.fill_(0)
    t_start = timeit.default_timer()
    # handling burnin, get loader_iter and learning rate
    loader_iter, lr = data_loader_lr(data, epoch, progress = progress)
    
    for i_batch, (inputs, targets) in enumerate(loader_iter):
      elapsed = timeit.default_timer() - t_start
      inputs = inputs.to(device); targets = targets.to(device)      
      optimizer.zero_grad()
      preds = model(inputs)
      loss = model.loss(preds, targets, size_average=True)
      loss.backward()
      optimizer.step(lr=lr)
      epoch_loss[i_batch] = loss.cpu().item()
      
    LOSS[epoch] = torch.mean(epoch_loss).item()
    # since only one thread is used:
    log.info('json_stats: {' f'"epoch": {epoch}, ' \
    f'"elapsed": {elapsed}, ' f'"loss": {LOSS[epoch]}, ' '}')
  return

# %% [markdown]
# # Training embedding

# %%
# setup model
# manifold = PoincareManifold(
#     debug=opt_debug, max_norm=opt_maxnorm, com_n=opt_com_n)
manifold = MANIFOLDS[opt_manifold](
        debug=opt_debug, max_norm=opt_maxnorm, com_n=opt_com_n)
model, data, model_name, conf = init_model(
    manifold, idx, objects, weights, sparse=opt_sparse)
data.neg_multiplier = opt_neg_multiplier
train._lr_multiplier = opt_burnin_multiplier
model = model.to(device)
print('the total dimension', model.lt.weight.data.size(-1), 'com_n', opt_com_n)

# setup optimizer
optimizer = RiemannianSGD(model.optim_params(manifold), lr= opt_lr)
# get adjacency matrix
adj = adj_matrix(data) 
# begin training
start_time = timeit.default_timer()
train(device, model, data, optimizer, progress=False )
print("Total training time is:", timeit.default_timer() - start_time)
# Out:
# >>>>>> The size of embedding: Embedding(1180, 2, sparse=True)
# the total dimension 2 com_n 1
# 1.0001 is the largest absolute weight in the embedding
# json_stats: {"epoch": 0, "elapsed": 0.7073092339996947, "loss": 3.9310063038169822, }
# 1.007937 is the largest absolute weight in the embedding
# json_stats: {"epoch": 1, "elapsed": 0.6546156990007148, "loss": 3.9289632965430576, }
# 1.015105 is the largest absolute weight in the embedding
# json_stats: {"epoch": 2, "elapsed": 0.7056052059997455, "loss": 3.9268504104365176, }
# 1.022333 is the largest absolute weight in the embedding
# json_stats: {"epoch": 3, "elapsed": 0.666222685998946, "loss": 3.924738146599456, }
# 1.029571 is the largest absolute weight in the embedding
# json_stats: {"epoch": 4, "elapsed": 0.6578724759965553, "loss": 3.9226144791975717, }
# 1.036596 is the largest absolute weight in the embedding
# json_stats: {"epoch": 5, "elapsed": 0.668765058995632, "loss": 3.920505856988451, }
# 1.043794 is the largest absolute weight in the embedding
# json_stats: {"epoch": 6, "elapsed": 0.6484292480017757, "loss": 3.9183906321627804, }
# 1.051153 is the largest absolute weight in the embedding
# json_stats: {"epoch": 7, "elapsed": 0.6614683700026944, "loss": 3.9162583009759033, }
# 1.058485 is the largest absolute weight in the embedding
# json_stats: {"epoch": 8, "elapsed": 0.6453616639992106, "loss": 3.914168236202392, }
# 1.065892 is the largest absolute weight in the embedding
# json_stats: {"epoch": 9, "elapsed": 0.6798683070010156, "loss": 3.9120705856346865, }
# 1.073251 is the largest absolute weight in the embedding
# json_stats: {"epoch": 10, "elapsed": 0.6462594640033785, "loss": 3.9099947762743565, }
# 1.080773 is the largest absolute weight in the embedding
# json_stats: {"epoch": 11, "elapsed": 0.6468196340065333, "loss": 3.907906034052175, }
# 1.088028 is the largest absolute weight in the embedding
# json_stats: {"epoch": 12, "elapsed": 0.6738870469998801, "loss": 3.9058300758941087, }
# 1.095458 is the largest absolute weight in the embedding
# json_stats: {"epoch": 13, "elapsed": 0.6846895290000248, "loss": 3.9037411528772585, }
# 1.102745 is the largest absolute weight in the embedding
# json_stats: {"epoch": 14, "elapsed": 0.6446618039990426, "loss": 3.9016806220122953, }
# 1.110092 is the largest absolute weight in the embedding
# json_stats: {"epoch": 15, "elapsed": 0.6692303990057553, "loss": 3.8996061176834513, }
# 1.117451 is the largest absolute weight in the embedding
# json_stats: {"epoch": 16, "elapsed": 0.6442496800009394, "loss": 3.8975736666045857, }
# 1.124892 is the largest absolute weight in the embedding
# json_stats: {"epoch": 17, "elapsed": 0.6303202590061119, "loss": 3.8955381478968096, }
# 1.132304 is the largest absolute weight in the embedding
# json_stats: {"epoch": 18, "elapsed": 0.650592225996661, "loss": 3.893505406419843, }
# 1.139542 is the largest absolute weight in the embedding
# json_stats: {"epoch": 19, "elapsed": 0.6733403070029453, "loss": 3.891469632938995, }
# 1.146845 is the largest absolute weight in the embedding
# json_stats: {"epoch": 20, "elapsed": 0.7490879670003778, "loss": 3.889853298878368, }
# 1.330872 is the largest absolute weight in the embedding
# json_stats: {"epoch": 21, "elapsed": 0.7558104380004806, "loss": 3.794215845239146, }
# 1.634304 is the largest absolute weight in the embedding
# json_stats: {"epoch": 22, "elapsed": 0.8014141940002446, "loss": 3.6999093738441613, }
# 1.919326 is the largest absolute weight in the embedding
# json_stats: {"epoch": 23, "elapsed": 0.7815623269998468, "loss": 3.6134333614783585, }
# 2.235445 is the largest absolute weight in the embedding
# json_stats: {"epoch": 24, "elapsed": 0.8012225150014274, "loss": 3.5348133927562295, }
# 2.659726 is the largest absolute weight in the embedding
# json_stats: {"epoch": 25, "elapsed": 0.7508881570029189, "loss": 3.4616561349724857, }
# 3.09321 is the largest absolute weight in the embedding
# json_stats: {"epoch": 26, "elapsed": 0.7946829789943877, "loss": 3.3970534498497202, }
# 3.592646 is the largest absolute weight in the embedding
# json_stats: {"epoch": 27, "elapsed": 0.7261412770021707, "loss": 3.336140002017071, }
# 4.150414 is the largest absolute weight in the embedding
# json_stats: {"epoch": 28, "elapsed": 0.7445073300041258, "loss": 3.278857370273631, }
# 4.869561 is the largest absolute weight in the embedding
# json_stats: {"epoch": 29, "elapsed": 0.7452121759997681, "loss": 3.2257879613218248, }
# 5.552188 is the largest absolute weight in the embedding
# json_stats: {"epoch": 30, "elapsed": 0.7480102629997418, "loss": 3.178408816448049, }
# 6.429938 is the largest absolute weight in the embedding
# json_stats: {"epoch": 31, "elapsed": 0.8050026769997203, "loss": 3.1327777783528523, }
# 7.345376 is the largest absolute weight in the embedding
# json_stats: {"epoch": 32, "elapsed": 0.7844511450020946, "loss": 3.0899430459667294, }
# 8.305922 is the largest absolute weight in the embedding
# json_stats: {"epoch": 33, "elapsed": 0.7738189719966613, "loss": 3.05518149413091, }
# 9.345158 is the largest absolute weight in the embedding
# json_stats: {"epoch": 34, "elapsed": 0.7610252000013134, "loss": 3.0171597554209333, }
# 10.559497 is the largest absolute weight in the embedding
# json_stats: {"epoch": 35, "elapsed": 0.8684101059989189, "loss": 2.9851296648816144, }
# 11.928234 is the largest absolute weight in the embedding
# json_stats: {"epoch": 36, "elapsed": 0.7562163929978851, "loss": 2.9521434182025175, }
# 13.341494 is the largest absolute weight in the embedding
# json_stats: {"epoch": 37, "elapsed": 0.7562621229953947, "loss": 2.9224826759414384, }
# 15.032572 is the largest absolute weight in the embedding
# json_stats: {"epoch": 38, "elapsed": 0.7794760590040823, "loss": 2.8946485833300866, }
# 16.481154 is the largest absolute weight in the embedding
# json_stats: {"epoch": 39, "elapsed": 0.7750999209965812, "loss": 2.8681571740980756, }
# 18.268391 is the largest absolute weight in the embedding
# json_stats: {"epoch": 40, "elapsed": 0.7466452189983102, "loss": 2.839985810039261, }
# 20.447072 is the largest absolute weight in the embedding
# json_stats: {"epoch": 41, "elapsed": 0.7534446950012352, "loss": 2.816007996480102, }
# 22.684154 is the largest absolute weight in the embedding
# json_stats: {"epoch": 42, "elapsed": 0.7376328050013399, "loss": 2.790291184862098, }
# 24.805213 is the largest absolute weight in the embedding
# json_stats: {"epoch": 43, "elapsed": 0.7390519539985689, "loss": 2.7692996458781765, }
# 27.573897 is the largest absolute weight in the embedding
# json_stats: {"epoch": 44, "elapsed": 0.7452441150016966, "loss": 2.7474705955780534, }
# 30.035645 is the largest absolute weight in the embedding
# json_stats: {"epoch": 45, "elapsed": 0.7391254950052826, "loss": 2.7230032790498218, }
# 32.85356 is the largest absolute weight in the embedding
# json_stats: {"epoch": 46, "elapsed": 0.7240074539950001, "loss": 2.710029821962301, }
# 35.057399 is the largest absolute weight in the embedding
# json_stats: {"epoch": 47, "elapsed": 0.7211221699981252, "loss": 2.691366990938633, }
# 37.827535 is the largest absolute weight in the embedding
# json_stats: {"epoch": 48, "elapsed": 0.7325226290049613, "loss": 2.674079795743614, }
# 40.327019 is the largest absolute weight in the embedding
# json_stats: {"epoch": 49, "elapsed": 0.7151834100004635, "loss": 2.6577838952227846, }
# 42.61643 is the largest absolute weight in the embedding
# json_stats: {"epoch": 50, "elapsed": 0.7187471880024532, "loss": 2.6339464658085947, }
# 44.059839 is the largest absolute weight in the embedding
# json_stats: {"epoch": 51, "elapsed": 0.7274653470012709, "loss": 2.627032770965358, }
# 47.413088 is the largest absolute weight in the embedding
# json_stats: {"epoch": 52, "elapsed": 0.7150068700066186, "loss": 2.617263180714686, }
# 50.497689 is the largest absolute weight in the embedding
# json_stats: {"epoch": 53, "elapsed": 0.7222076500038384, "loss": 2.595414593678848, }
# 54.313996 is the largest absolute weight in the embedding
# json_stats: {"epoch": 54, "elapsed": 0.7229984139994485, "loss": 2.581058326042472, }
# 56.401114 is the largest absolute weight in the embedding
# json_stats: {"epoch": 55, "elapsed": 0.7423384369976702, "loss": 2.563710981353292, }
# 60.247276 is the largest absolute weight in the embedding
# json_stats: {"epoch": 56, "elapsed": 0.7258169029955752, "loss": 2.560372336063375, }
# 65.668134 is the largest absolute weight in the embedding
# json_stats: {"epoch": 57, "elapsed": 0.7284672769965255, "loss": 2.547217509573776, }
# 68.415579 is the largest absolute weight in the embedding
# json_stats: {"epoch": 58, "elapsed": 0.7173323090028134, "loss": 2.5330568110371625, }
# 72.682871 is the largest absolute weight in the embedding
# json_stats: {"epoch": 59, "elapsed": 0.7309850599995116, "loss": 2.516362468199175, }
# 76.399355 is the largest absolute weight in the embedding
# json_stats: {"epoch": 60, "elapsed": 0.7185383629985154, "loss": 2.5065511319356824, }
# 77.727446 is the largest absolute weight in the embedding
# json_stats: {"epoch": 61, "elapsed": 0.7108759980037576, "loss": 2.4925365527257326, }
# 81.99287 is the largest absolute weight in the embedding
# json_stats: {"epoch": 62, "elapsed": 0.7499929729965515, "loss": 2.4864232108293716, }
# 87.226456 is the largest absolute weight in the embedding
# json_stats: {"epoch": 63, "elapsed": 0.7178382870042697, "loss": 2.471229832771365, }
# 90.144627 is the largest absolute weight in the embedding
# json_stats: {"epoch": 64, "elapsed": 0.7292374699973152, "loss": 2.4617991095975746, }
# 95.3198 is the largest absolute weight in the embedding
# json_stats: {"epoch": 65, "elapsed": 0.7144619309983682, "loss": 2.4616804231530725, }
# 98.939768 is the largest absolute weight in the embedding
# json_stats: {"epoch": 66, "elapsed": 0.7215224910032703, "loss": 2.4474859726910045, }
# 103.100166 is the largest absolute weight in the embedding
# json_stats: {"epoch": 67, "elapsed": 0.7233598140010145, "loss": 2.427001314178262, }
# 108.204015 is the largest absolute weight in the embedding
# json_stats: {"epoch": 68, "elapsed": 0.7449879699997837, "loss": 2.4194252498928543, }
# 111.898849 is the largest absolute weight in the embedding
# json_stats: {"epoch": 69, "elapsed": 0.7380544349944103, "loss": 2.4057911342851748, }
# 113.898792 is the largest absolute weight in the embedding
# json_stats: {"epoch": 70, "elapsed": 0.7372162749961717, "loss": 2.401577875560153, }
# 114.249816 is the largest absolute weight in the embedding
# json_stats: {"epoch": 71, "elapsed": 0.7288990509987343, "loss": 2.401802478619583, }
# 120.179426 is the largest absolute weight in the embedding
# json_stats: {"epoch": 72, "elapsed": 0.7539998290012591, "loss": 2.384597115980653, }
# 122.7711 is the largest absolute weight in the embedding
# json_stats: {"epoch": 73, "elapsed": 0.7426632530041388, "loss": 2.376307354253098, }
# 129.078346 is the largest absolute weight in the embedding
# json_stats: {"epoch": 74, "elapsed": 0.7459265799989225, "loss": 2.3556132093307762, }
# 139.777792 is the largest absolute weight in the embedding
# json_stats: {"epoch": 75, "elapsed": 0.7302817900053924, "loss": 2.353080901622271, }
# 145.050887 is the largest absolute weight in the embedding
# json_stats: {"epoch": 76, "elapsed": 0.7606260100001236, "loss": 2.340156089458696, }
# 152.587848 is the largest absolute weight in the embedding
# json_stats: {"epoch": 77, "elapsed": 0.7290588949981611, "loss": 2.3326137123743305, }
# 159.866047 is the largest absolute weight in the embedding
# json_stats: {"epoch": 78, "elapsed": 0.7439950810003211, "loss": 2.32723521516361, }
# 167.670518 is the largest absolute weight in the embedding
# json_stats: {"epoch": 79, "elapsed": 0.7586789359993418, "loss": 2.3152461589318336, }
# 172.547292 is the largest absolute weight in the embedding
# json_stats: {"epoch": 80, "elapsed": 0.7181671419966733, "loss": 2.310081934906406, }
# 181.786882 is the largest absolute weight in the embedding
# json_stats: {"epoch": 81, "elapsed": 0.7103096630016807, "loss": 2.3025668316482126, }
# 193.504604 is the largest absolute weight in the embedding
# json_stats: {"epoch": 82, "elapsed": 0.7142918999961694, "loss": 2.2926173563341705, }
# 202.694694 is the largest absolute weight in the embedding
# json_stats: {"epoch": 83, "elapsed": 0.7169574029976502, "loss": 2.2844134339713866, }
# 209.587335 is the largest absolute weight in the embedding
# json_stats: {"epoch": 84, "elapsed": 0.7151414249965455, "loss": 2.2750247949868285, }
# 215.33153 is the largest absolute weight in the embedding
# json_stats: {"epoch": 85, "elapsed": 0.722269325000525, "loss": 2.2674559051885677, }
# 221.663588 is the largest absolute weight in the embedding
# json_stats: {"epoch": 86, "elapsed": 0.7189548069945886, "loss": 2.2628209018835617, }
# 228.706506 is the largest absolute weight in the embedding
# json_stats: {"epoch": 87, "elapsed": 0.7298955400037812, "loss": 2.2526936000634508, }
# 234.044185 is the largest absolute weight in the embedding
# json_stats: {"epoch": 88, "elapsed": 0.7396985890009091, "loss": 2.245011190651421, }
# 239.253029 is the largest absolute weight in the embedding
# json_stats: {"epoch": 89, "elapsed": 0.7258723330014618, "loss": 2.225128950773086, }
# 241.445914 is the largest absolute weight in the embedding
# json_stats: {"epoch": 90, "elapsed": 0.7270578619936714, "loss": 2.2201634269641297, }
# 247.707548 is the largest absolute weight in the embedding
# json_stats: {"epoch": 91, "elapsed": 0.726761357000214, "loss": 2.2119756590418893, }
# 251.074698 is the largest absolute weight in the embedding
# json_stats: {"epoch": 92, "elapsed": 0.7256627329988987, "loss": 2.209153427064015, }
# 253.745519 is the largest absolute weight in the embedding
# json_stats: {"epoch": 93, "elapsed": 0.7188350960059324, "loss": 2.201881100589989, }
# 257.284126 is the largest absolute weight in the embedding
# json_stats: {"epoch": 94, "elapsed": 0.7162099989946, "loss": 2.19363698858673, }
# 259.05633 is the largest absolute weight in the embedding
# json_stats: {"epoch": 95, "elapsed": 0.7331119580048835, "loss": 2.193072820692871, }
# 260.804337 is the largest absolute weight in the embedding
# json_stats: {"epoch": 96, "elapsed": 0.7496562930027721, "loss": 2.176205582890634, }
# 270.318121 is the largest absolute weight in the embedding
# json_stats: {"epoch": 97, "elapsed": 0.739527233003173, "loss": 2.1678058550047368, }
# 289.676338 is the largest absolute weight in the embedding
# json_stats: {"epoch": 98, "elapsed": 0.7260778420022689, "loss": 2.159214378547694, }
# 301.866553 is the largest absolute weight in the embedding
# json_stats: {"epoch": 99, "elapsed": 0.7423673230005079, "loss": 2.156042114413116, }
# 325.781438 is the largest absolute weight in the embedding
# json_stats: {"epoch": 100, "elapsed": 0.7491301929985639, "loss": 2.1437488666453937, }
# 341.218025 is the largest absolute weight in the embedding
# json_stats: {"epoch": 101, "elapsed": 0.727663196004869, "loss": 2.1445522082809343, }
# 353.796178 is the largest absolute weight in the embedding
# json_stats: {"epoch": 102, "elapsed": 0.7278258820006158, "loss": 2.1189430418175927, }
# 381.566429 is the largest absolute weight in the embedding
# json_stats: {"epoch": 103, "elapsed": 0.7211612109967973, "loss": 2.120779278696717, }
# 405.39538 is the largest absolute weight in the embedding
# json_stats: {"epoch": 104, "elapsed": 0.7200805569955264, "loss": 2.117008905532272, }
# 438.791615 is the largest absolute weight in the embedding
# json_stats: {"epoch": 105, "elapsed": 0.7424696130037773, "loss": 2.0998841628488525, }
# 475.922516 is the largest absolute weight in the embedding
# json_stats: {"epoch": 106, "elapsed": 0.7404420879975078, "loss": 2.0939135754514595, }
# 517.530514 is the largest absolute weight in the embedding
# json_stats: {"epoch": 107, "elapsed": 0.7473326190010994, "loss": 2.0941257574632854, }
# 537.435316 is the largest absolute weight in the embedding
# json_stats: {"epoch": 108, "elapsed": 0.7213909959973535, "loss": 2.086681285320499, }
# 565.911891 is the largest absolute weight in the embedding
# json_stats: {"epoch": 109, "elapsed": 0.7234216340002604, "loss": 2.071507941684862, }
# 584.178392 is the largest absolute weight in the embedding
# json_stats: {"epoch": 110, "elapsed": 0.728835331996379, "loss": 2.0681233395092526, }
# 625.333533 is the largest absolute weight in the embedding
# json_stats: {"epoch": 111, "elapsed": 0.710619397003029, "loss": 2.047798032140069, }
# 652.899692 is the largest absolute weight in the embedding
# json_stats: {"epoch": 112, "elapsed": 0.7120761320038582, "loss": 2.0497497102712474, }
# 660.228485 is the largest absolute weight in the embedding
# json_stats: {"epoch": 113, "elapsed": 0.7384618549986044, "loss": 2.0306558071434733, }
# 681.25901 is the largest absolute weight in the embedding
# json_stats: {"epoch": 114, "elapsed": 0.731751974002691, "loss": 2.0269519951684836, }
# 698.626627 is the largest absolute weight in the embedding
# json_stats: {"epoch": 115, "elapsed": 0.7228466849992401, "loss": 2.0124488421888738, }
# 730.051146 is the largest absolute weight in the embedding
# json_stats: {"epoch": 116, "elapsed": 0.7444866300065769, "loss": 2.002137846691616, }
# 755.277915 is the largest absolute weight in the embedding
# json_stats: {"epoch": 117, "elapsed": 0.7378489299953799, "loss": 1.9940955870297565, }
# 778.47505 is the largest absolute weight in the embedding
# json_stats: {"epoch": 118, "elapsed": 0.7206015909978305, "loss": 1.997200831196227, }
# 794.538 is the largest absolute weight in the embedding
# json_stats: {"epoch": 119, "elapsed": 0.7411090629975661, "loss": 1.9838139788474778, }
# 813.725711 is the largest absolute weight in the embedding
# json_stats: {"epoch": 120, "elapsed": 0.7315562389994739, "loss": 1.9712834657118607, }
# 826.025514 is the largest absolute weight in the embedding
# json_stats: {"epoch": 121, "elapsed": 0.7214594749966636, "loss": 1.9614820671243134, }
# 833.938147 is the largest absolute weight in the embedding
# json_stats: {"epoch": 122, "elapsed": 0.7178650579953683, "loss": 1.9504342440401419, }
# 846.968284 is the largest absolute weight in the embedding
# json_stats: {"epoch": 123, "elapsed": 0.7228197149961488, "loss": 1.9579341882616326, }
# 848.758759 is the largest absolute weight in the embedding
# json_stats: {"epoch": 124, "elapsed": 0.7110932080031489, "loss": 1.9290942126875956, }
# 847.449485 is the largest absolute weight in the embedding
# json_stats: {"epoch": 125, "elapsed": 0.729310025999439, "loss": 1.9154617683479183, }
# 852.673357 is the largest absolute weight in the embedding
# json_stats: {"epoch": 126, "elapsed": 0.7365808710019337, "loss": 1.9162152095178344, }
# 900.832359 is the largest absolute weight in the embedding
# json_stats: {"epoch": 127, "elapsed": 0.7164299379946897, "loss": 1.9048737092102568, }
# 920.347192 is the largest absolute weight in the embedding
# json_stats: {"epoch": 128, "elapsed": 0.7301232350000646, "loss": 1.8951057581990314, }
# 949.687566 is the largest absolute weight in the embedding
# json_stats: {"epoch": 129, "elapsed": 0.7497930469980929, "loss": 1.878525279168599, }
# 978.485409 is the largest absolute weight in the embedding
# json_stats: {"epoch": 130, "elapsed": 0.7177463679981884, "loss": 1.8809879307656558, }
# 1036.289315 is the largest absolute weight in the embedding
# json_stats: {"epoch": 131, "elapsed": 0.7379860450018896, "loss": 1.8680444186296723, }
# 1064.904507 is the largest absolute weight in the embedding
# json_stats: {"epoch": 132, "elapsed": 0.7086159680038691, "loss": 1.8418516363256239, }
# 1101.974195 is the largest absolute weight in the embedding
# json_stats: {"epoch": 133, "elapsed": 0.7155603999999585, "loss": 1.853489421280861, }
# 1145.326862 is the largest absolute weight in the embedding
# json_stats: {"epoch": 134, "elapsed": 0.7355803719983669, "loss": 1.8313012570628102, }
# 1195.57122 is the largest absolute weight in the embedding
# json_stats: {"epoch": 135, "elapsed": 0.7289450809985283, "loss": 1.8280831983506332, }
# 1227.812004 is the largest absolute weight in the embedding
# json_stats: {"epoch": 136, "elapsed": 0.7243972130017937, "loss": 1.7920764889304388, }
# 1249.341773 is the largest absolute weight in the embedding
# json_stats: {"epoch": 137, "elapsed": 0.7331702380033676, "loss": 1.8039489804904516, }
# 1275.653974 is the largest absolute weight in the embedding
# json_stats: {"epoch": 138, "elapsed": 0.72112410000409, "loss": 1.788340181117891, }
# 1286.851979 is the largest absolute weight in the embedding
# json_stats: {"epoch": 139, "elapsed": 0.7174933529968257, "loss": 1.7683617209733937, }
# 1300.429658 is the largest absolute weight in the embedding
# json_stats: {"epoch": 140, "elapsed": 0.7251222080012667, "loss": 1.7539504602579497, }
# 1315.318272 is the largest absolute weight in the embedding
# json_stats: {"epoch": 141, "elapsed": 0.7478688640039763, "loss": 1.7545544229804604, }
# 1325.706954 is the largest absolute weight in the embedding
# json_stats: {"epoch": 142, "elapsed": 0.721195270998578, "loss": 1.7401892983682397, }
# 1334.529636 is the largest absolute weight in the embedding
# json_stats: {"epoch": 143, "elapsed": 0.7238453590034624, "loss": 1.7364907472729543, }
# 1347.54507 is the largest absolute weight in the embedding
# json_stats: {"epoch": 144, "elapsed": 0.7447651899929042, "loss": 1.7193561822406993, }
# 1374.317589 is the largest absolute weight in the embedding
# json_stats: {"epoch": 145, "elapsed": 0.7298182609956712, "loss": 1.6902397811990284, }
# 1389.201518 is the largest absolute weight in the embedding
# json_stats: {"epoch": 146, "elapsed": 0.7436792770022294, "loss": 1.6796235986122636, }
# 1410.350227 is the largest absolute weight in the embedding
# json_stats: {"epoch": 147, "elapsed": 0.7507469519987353, "loss": 1.6713444616779731, }
# 1433.454545 is the largest absolute weight in the embedding
# json_stats: {"epoch": 148, "elapsed": 0.8031575629938743, "loss": 1.664366653269348, }
# 1438.836258 is the largest absolute weight in the embedding
# json_stats: {"epoch": 149, "elapsed": 0.7542217150039505, "loss": 1.6596841292670772, }
# 1447.407206 is the largest absolute weight in the embedding
# json_stats: {"epoch": 150, "elapsed": 0.7977100019998034, "loss": 1.6297361689897483, }
# 1451.471959 is the largest absolute weight in the embedding
# json_stats: {"epoch": 151, "elapsed": 0.7551615880001918, "loss": 1.6244152479618017, }
# 1502.880539 is the largest absolute weight in the embedding
# json_stats: {"epoch": 152, "elapsed": 0.712492356004077, "loss": 1.6118432200699595, }
# 1531.928087 is the largest absolute weight in the embedding
# json_stats: {"epoch": 153, "elapsed": 0.7299303250038065, "loss": 1.58975374003112, }
# 1587.174801 is the largest absolute weight in the embedding
# json_stats: {"epoch": 154, "elapsed": 0.7365096599969547, "loss": 1.5811070715414282, }
# 1606.460051 is the largest absolute weight in the embedding
# json_stats: {"epoch": 155, "elapsed": 0.7174931379995542, "loss": 1.5623185369038137, }
# 1621.382917 is the largest absolute weight in the embedding
# json_stats: {"epoch": 156, "elapsed": 0.7113034819994937, "loss": 1.5394894852844196, }
# 1698.455422 is the largest absolute weight in the embedding
# json_stats: {"epoch": 157, "elapsed": 0.7143242449965328, "loss": 1.5177913463646031, }
# 1744.88073 is the largest absolute weight in the embedding
# json_stats: {"epoch": 158, "elapsed": 0.7202747260016622, "loss": 1.5102215427983054, }
# 1769.737615 is the largest absolute weight in the embedding
# json_stats: {"epoch": 159, "elapsed": 0.7209080009997706, "loss": 1.5018554253936092, }
# 1801.651593 is the largest absolute weight in the embedding
# json_stats: {"epoch": 160, "elapsed": 0.7203517609959817, "loss": 1.4868808903913104, }
# 1821.275709 is the largest absolute weight in the embedding
# json_stats: {"epoch": 161, "elapsed": 0.7324556490057148, "loss": 1.4646607912909302, }
# 1848.537462 is the largest absolute weight in the embedding
# json_stats: {"epoch": 162, "elapsed": 0.7446608800019021, "loss": 1.4499745930602252, }
# 1864.160436 is the largest absolute weight in the embedding
# json_stats: {"epoch": 163, "elapsed": 0.7093846429997939, "loss": 1.4303630248683195, }
# 1869.272191 is the largest absolute weight in the embedding
# json_stats: {"epoch": 164, "elapsed": 0.7187529959992389, "loss": 1.4063121010354958, }
# 1878.506577 is the largest absolute weight in the embedding
# json_stats: {"epoch": 165, "elapsed": 0.7345810280021396, "loss": 1.4080068279385627, }
# 1905.951956 is the largest absolute weight in the embedding
# json_stats: {"epoch": 166, "elapsed": 0.7283782160011469, "loss": 1.3756509389403146, }
# 1911.629875 is the largest absolute weight in the embedding
# json_stats: {"epoch": 167, "elapsed": 0.7125154619934619, "loss": 1.3459108645704654, }
# 1926.757584 is the largest absolute weight in the embedding
# json_stats: {"epoch": 168, "elapsed": 0.7084174440024071, "loss": 1.3356728186224451, }
# 1950.613647 is the largest absolute weight in the embedding
# json_stats: {"epoch": 169, "elapsed": 0.7001224699997692, "loss": 1.321744615134548, }
# 1962.716411 is the largest absolute weight in the embedding
# json_stats: {"epoch": 170, "elapsed": 0.7235366340028122, "loss": 1.2894692661850866, }
# 1970.38907 is the largest absolute weight in the embedding
# json_stats: {"epoch": 171, "elapsed": 0.7423406430025352, "loss": 1.293776123444337, }
# 1977.833123 is the largest absolute weight in the embedding
# json_stats: {"epoch": 172, "elapsed": 0.7090644179988885, "loss": 1.2643822716533768, }
# 1984.354091 is the largest absolute weight in the embedding
# json_stats: {"epoch": 173, "elapsed": 0.7025793729990255, "loss": 1.2354624065386355, }
# 1995.671285 is the largest absolute weight in the embedding
# json_stats: {"epoch": 174, "elapsed": 0.7081336090050172, "loss": 1.224162969815948, }
# 1998.494899 is the largest absolute weight in the embedding
# json_stats: {"epoch": 175, "elapsed": 0.7199616760044592, "loss": 1.193975377308423, }
# 2004.001667 is the largest absolute weight in the embedding
# json_stats: {"epoch": 176, "elapsed": 0.719651655999769, "loss": 1.153666125181851, }
# 2010.453901 is the largest absolute weight in the embedding
# json_stats: {"epoch": 177, "elapsed": 0.7262753519971739, "loss": 1.1529225390293394, }
# 2016.491255 is the largest absolute weight in the embedding
# json_stats: {"epoch": 178, "elapsed": 0.7216494399981457, "loss": 1.1276348159170162, }
# 2020.749351 is the largest absolute weight in the embedding
# json_stats: {"epoch": 179, "elapsed": 0.7476748289991519, "loss": 1.1111793898226978, }
# 2027.157874 is the largest absolute weight in the embedding
# json_stats: {"epoch": 180, "elapsed": 0.7553547339994111, "loss": 1.1091551922454288, }
# 2031.862743 is the largest absolute weight in the embedding
# json_stats: {"epoch": 181, "elapsed": 0.7266693130004569, "loss": 1.0884460098891824, }
# 2035.705308 is the largest absolute weight in the embedding
# json_stats: {"epoch": 182, "elapsed": 0.7270299480005633, "loss": 1.0648362485135316, }
# 2038.860682 is the largest absolute weight in the embedding
# json_stats: {"epoch": 183, "elapsed": 0.7237359789942275, "loss": 0.9966667818185329, }
# 2044.909704 is the largest absolute weight in the embedding
# json_stats: {"epoch": 184, "elapsed": 0.7245392539989552, "loss": 1.03582579417564, }
# 2045.562036 is the largest absolute weight in the embedding
# json_stats: {"epoch": 185, "elapsed": 0.7754824910007301, "loss": 0.9909355470649586, }
# 2049.467798 is the largest absolute weight in the embedding
# json_stats: {"epoch": 186, "elapsed": 0.7403560630045831, "loss": 0.953840180513626, }
# 2050.209314 is the largest absolute weight in the embedding
# json_stats: {"epoch": 187, "elapsed": 0.7331917379997321, "loss": 0.9632014941392864, }
# 2051.144106 is the largest absolute weight in the embedding
# json_stats: {"epoch": 188, "elapsed": 0.716144489000726, "loss": 0.9389769936932035, }
# 2052.256963 is the largest absolute weight in the embedding
# json_stats: {"epoch": 189, "elapsed": 0.7284266709975782, "loss": 0.9276840177417035, }
# 2053.761661 is the largest absolute weight in the embedding
# json_stats: {"epoch": 190, "elapsed": 0.7288163809935213, "loss": 0.9171946405286137, }
# 2054.516303 is the largest absolute weight in the embedding
# json_stats: {"epoch": 191, "elapsed": 0.7342782569976407, "loss": 0.8739955794041733, }
# 2055.032684 is the largest absolute weight in the embedding
# json_stats: {"epoch": 192, "elapsed": 0.7107076129977941, "loss": 0.8669590467979257, }
# 2055.465654 is the largest absolute weight in the embedding
# json_stats: {"epoch": 193, "elapsed": 0.7280107520055026, "loss": 0.8738332310184418, }
# 2055.681203 is the largest absolute weight in the embedding
# json_stats: {"epoch": 194, "elapsed": 0.7432023509973078, "loss": 0.8351321805693264, }
# 2056.326942 is the largest absolute weight in the embedding
# json_stats: {"epoch": 195, "elapsed": 0.7248171489991364, "loss": 0.8128886576372393, }
# 2057.419058 is the largest absolute weight in the embedding
# json_stats: {"epoch": 196, "elapsed": 0.7234896040026797, "loss": 0.8112843340822853, }
# 2058.06068 is the largest absolute weight in the embedding
# json_stats: {"epoch": 197, "elapsed": 0.7268867419988965, "loss": 0.7922885377048582, }
# 2059.101524 is the largest absolute weight in the embedding
# json_stats: {"epoch": 198, "elapsed": 0.7420927819985081, "loss": 0.7596400201084536, }
# 2060.701514 is the largest absolute weight in the embedding
# json_stats: {"epoch": 199, "elapsed": 0.7345481420052238, "loss": 0.7536817596911775, }
# 2061.506783 is the largest absolute weight in the embedding
# json_stats: {"epoch": 200, "elapsed": 0.7333994279979379, "loss": 0.757773073941572, }
# 2062.566715 is the largest absolute weight in the embedding
# json_stats: {"epoch": 201, "elapsed": 0.7452803199994378, "loss": 0.7462069566147398, }
# 2062.714299 is the largest absolute weight in the embedding
# json_stats: {"epoch": 202, "elapsed": 0.7185199779996765, "loss": 0.712013477196687, }
# 2062.758723 is the largest absolute weight in the embedding
# json_stats: {"epoch": 203, "elapsed": 0.7237195640045684, "loss": 0.7021626163678764, }
# 2062.991255 is the largest absolute weight in the embedding
# json_stats: {"epoch": 204, "elapsed": 0.7247203029983211, "loss": 0.7110190691900656, }
# 2063.41184 is the largest absolute weight in the embedding
# json_stats: {"epoch": 205, "elapsed": 0.7359417510015192, "loss": 0.690656110883247, }
# 2063.731948 is the largest absolute weight in the embedding
# json_stats: {"epoch": 206, "elapsed": 0.7316049389992259, "loss": 0.6799642054634261, }
# 2063.921956 is the largest absolute weight in the embedding
# json_stats: {"epoch": 207, "elapsed": 0.7424427520018071, "loss": 0.681625117434294, }
# 2064.26372 is the largest absolute weight in the embedding
# json_stats: {"epoch": 208, "elapsed": 0.7484793280018494, "loss": 0.6310560644879452, }
# 2064.584667 is the largest absolute weight in the embedding
# json_stats: {"epoch": 209, "elapsed": 0.7202506469984655, "loss": 0.6244694643522962, }
# 2065.332746 is the largest absolute weight in the embedding
# json_stats: {"epoch": 210, "elapsed": 0.730179969999881, "loss": 0.6353181844896052, }
# 2065.932902 is the largest absolute weight in the embedding
# json_stats: {"epoch": 211, "elapsed": 0.7332718079996994, "loss": 0.6219082383289768, }
# 2066.159245 is the largest absolute weight in the embedding
# json_stats: {"epoch": 212, "elapsed": 0.7332871469989186, "loss": 0.6119159446684377, }
# 2066.771302 is the largest absolute weight in the embedding
# json_stats: {"epoch": 213, "elapsed": 0.7501065169999492, "loss": 0.6014376955704832, }
# 2066.958872 is the largest absolute weight in the embedding
# json_stats: {"epoch": 214, "elapsed": 0.7282892160001211, "loss": 0.5908133578865157, }
# 2067.08279 is the largest absolute weight in the embedding
# json_stats: {"epoch": 215, "elapsed": 0.751187725996715, "loss": 0.5882160177701746, }
# 2067.176478 is the largest absolute weight in the embedding
# json_stats: {"epoch": 216, "elapsed": 0.7495498630014481, "loss": 0.59382069430447, }
# 2067.309009 is the largest absolute weight in the embedding
# json_stats: {"epoch": 217, "elapsed": 0.7356424009994953, "loss": 0.5672505332376615, }
# 2067.384363 is the largest absolute weight in the embedding
# json_stats: {"epoch": 218, "elapsed": 0.7287258020005538, "loss": 0.552421627106964, }
# 2067.518608 is the largest absolute weight in the embedding
# json_stats: {"epoch": 219, "elapsed": 0.726991697003541, "loss": 0.5444930706827771, }
# 2067.622744 is the largest absolute weight in the embedding
# json_stats: {"epoch": 220, "elapsed": 0.752822410002409, "loss": 0.573378719640049, }
# 2067.668002 is the largest absolute weight in the embedding
# json_stats: {"epoch": 221, "elapsed": 0.7149294740011101, "loss": 0.5363997054596775, }
# 2067.616528 is the largest absolute weight in the embedding
# json_stats: {"epoch": 222, "elapsed": 0.7486415380044491, "loss": 0.5284746805035245, }
# 2067.737045 is the largest absolute weight in the embedding
# json_stats: {"epoch": 223, "elapsed": 0.7351193420035997, "loss": 0.5413999693147733, }
# 2067.766555 is the largest absolute weight in the embedding
# json_stats: {"epoch": 224, "elapsed": 0.7256614029975026, "loss": 0.5086334835452752, }
# 2067.888702 is the largest absolute weight in the embedding
# json_stats: {"epoch": 225, "elapsed": 0.7469567890002509, "loss": 0.5108288505856862, }
# 2067.942748 is the largest absolute weight in the embedding
# json_stats: {"epoch": 226, "elapsed": 0.7407135079993168, "loss": 0.5071312459390134, }
# 2068.042218 is the largest absolute weight in the embedding
# json_stats: {"epoch": 227, "elapsed": 0.7205189759988571, "loss": 0.509090054130177, }
# 2068.219818 is the largest absolute weight in the embedding
# json_stats: {"epoch": 228, "elapsed": 0.7329246839944972, "loss": 0.510502619248209, }
# 2068.268427 is the largest absolute weight in the embedding
# json_stats: {"epoch": 229, "elapsed": 0.7153355400005239, "loss": 0.4937207054891552, }
# 2068.40737 is the largest absolute weight in the embedding
# json_stats: {"epoch": 230, "elapsed": 0.7382781050037011, "loss": 0.4881672582979573, }
# 2068.477942 is the largest absolute weight in the embedding
# json_stats: {"epoch": 231, "elapsed": 0.7015851879987167, "loss": 0.4832380836626263, }
# 2068.604142 is the largest absolute weight in the embedding
# json_stats: {"epoch": 232, "elapsed": 0.7157436900015455, "loss": 0.4552546768164174, }
# 2068.65115 is the largest absolute weight in the embedding
# json_stats: {"epoch": 233, "elapsed": 0.7089909139976953, "loss": 0.47097585589199525, }
# 2068.689366 is the largest absolute weight in the embedding
# json_stats: {"epoch": 234, "elapsed": 0.7095746519989916, "loss": 0.4592822352375882, }
# 2068.727736 is the largest absolute weight in the embedding
# json_stats: {"epoch": 235, "elapsed": 0.707100725005148, "loss": 0.4555094874322713, }
# 2068.732817 is the largest absolute weight in the embedding
# json_stats: {"epoch": 236, "elapsed": 0.7122149410060956, "loss": 0.44474347651713003, }
# 2068.799115 is the largest absolute weight in the embedding
# json_stats: {"epoch": 237, "elapsed": 0.7169868249984575, "loss": 0.4440567244862874, }
# 2068.973938 is the largest absolute weight in the embedding
# json_stats: {"epoch": 238, "elapsed": 0.7262161870021373, "loss": 0.4395444875648704, }
# 2069.002674 is the largest absolute weight in the embedding
# json_stats: {"epoch": 239, "elapsed": 0.7216031149946502, "loss": 0.43516228070818413, }
# 2069.002299 is the largest absolute weight in the embedding
# json_stats: {"epoch": 240, "elapsed": 0.7150828689991613, "loss": 0.43787386240294945, }
# 2069.039416 is the largest absolute weight in the embedding
# json_stats: {"epoch": 241, "elapsed": 0.728258155999356, "loss": 0.42416380636112705, }
# 2069.08924 is the largest absolute weight in the embedding
# json_stats: {"epoch": 242, "elapsed": 0.7114463269972475, "loss": 0.41960141879298757, }
# 2069.097207 is the largest absolute weight in the embedding
# json_stats: {"epoch": 243, "elapsed": 0.7240689539976302, "loss": 0.40591401774995145, }
# 2069.146281 is the largest absolute weight in the embedding
# json_stats: {"epoch": 244, "elapsed": 0.7098421429982409, "loss": 0.4290540654965026, }
# 2069.162542 is the largest absolute weight in the embedding
# json_stats: {"epoch": 245, "elapsed": 0.7007213789984235, "loss": 0.40769591916055814, }
# 2069.185111 is the largest absolute weight in the embedding
# json_stats: {"epoch": 246, "elapsed": 0.7099850929953391, "loss": 0.408672701473633, }
# 2069.209884 is the largest absolute weight in the embedding
# json_stats: {"epoch": 247, "elapsed": 0.7141836559967487, "loss": 0.4007471556421915, }
# 2069.210565 is the largest absolute weight in the embedding
# json_stats: {"epoch": 248, "elapsed": 0.723902163997991, "loss": 0.38682742575902335, }
# 2069.276231 is the largest absolute weight in the embedding
# json_stats: {"epoch": 249, "elapsed": 0.7094568129978143, "loss": 0.38402440193652193, }
# 2069.29275 is the largest absolute weight in the embedding
# json_stats: {"epoch": 250, "elapsed": 0.7155962389952037, "loss": 0.39736626790382107, }
# 2069.302535 is the largest absolute weight in the embedding
# json_stats: {"epoch": 251, "elapsed": 0.7125036259967601, "loss": 0.39110245206280975, }
# 2069.325076 is the largest absolute weight in the embedding
# json_stats: {"epoch": 252, "elapsed": 0.7130902259959839, "loss": 0.373247012319279, }
# 2069.333023 is the largest absolute weight in the embedding
# json_stats: {"epoch": 253, "elapsed": 0.720504916003847, "loss": 0.37601174024157125, }
# 2069.37935 is the largest absolute weight in the embedding
# json_stats: {"epoch": 254, "elapsed": 0.7064881449987297, "loss": 0.3783728973518026, }
# 2069.401731 is the largest absolute weight in the embedding
# json_stats: {"epoch": 255, "elapsed": 0.7183961069968063, "loss": 0.3705722035814902, }
# 2069.410923 is the largest absolute weight in the embedding
# json_stats: {"epoch": 256, "elapsed": 0.7234682039998006, "loss": 0.35548462570967215, }
# 2069.463121 is the largest absolute weight in the embedding
# json_stats: {"epoch": 257, "elapsed": 0.7085367590043461, "loss": 0.35787528798376883, }
# 2069.466556 is the largest absolute weight in the embedding
# json_stats: {"epoch": 258, "elapsed": 0.7164452840006561, "loss": 0.35922158243451713, }
# 2069.492176 is the largest absolute weight in the embedding
# json_stats: {"epoch": 259, "elapsed": 0.7016008680002415, "loss": 0.3658403784104719, }
# 2069.516973 is the largest absolute weight in the embedding
# json_stats: {"epoch": 260, "elapsed": 0.7075151349999942, "loss": 0.3625879677775061, }
# 2069.532604 is the largest absolute weight in the embedding
# json_stats: {"epoch": 261, "elapsed": 0.7342158530009328, "loss": 0.3614051343436286, }
# 2069.547467 is the largest absolute weight in the embedding
# json_stats: {"epoch": 262, "elapsed": 0.7442848909995519, "loss": 0.3634464203944247, }
# 2069.559951 is the largest absolute weight in the embedding
# json_stats: {"epoch": 263, "elapsed": 0.7726800520031247, "loss": 0.35188019721221664, }
# 2069.56721 is the largest absolute weight in the embedding
# json_stats: {"epoch": 264, "elapsed": 0.7406219179974869, "loss": 0.34435828675947894, }
# 2069.594564 is the largest absolute weight in the embedding
# json_stats: {"epoch": 265, "elapsed": 0.8366399810038274, "loss": 0.3513376110432029, }
# 2069.58504 is the largest absolute weight in the embedding
# json_stats: {"epoch": 266, "elapsed": 0.846974455002055, "loss": 0.35939319567443223, }
# 2069.592822 is the largest absolute weight in the embedding
# json_stats: {"epoch": 267, "elapsed": 0.753888844003086, "loss": 0.3534331155378251, }
# 2069.599071 is the largest absolute weight in the embedding
# json_stats: {"epoch": 268, "elapsed": 0.7270503569961875, "loss": 0.33294195172077495, }
# 2069.621685 is the largest absolute weight in the embedding
# json_stats: {"epoch": 269, "elapsed": 0.7149872049994883, "loss": 0.32803443716593683, }
# 2069.644369 is the largest absolute weight in the embedding
# json_stats: {"epoch": 270, "elapsed": 0.81607827499829, "loss": 0.33561576505223734, }
# 2069.65635 is the largest absolute weight in the embedding
# json_stats: {"epoch": 271, "elapsed": 0.7445362159996876, "loss": 0.3258856419728471, }
# 2069.698037 is the largest absolute weight in the embedding
# json_stats: {"epoch": 272, "elapsed": 0.7617942800061428, "loss": 0.33357780093602296, }
# 2069.700325 is the largest absolute weight in the embedding
# json_stats: {"epoch": 273, "elapsed": 0.7379551250051009, "loss": 0.31566230311955895, }
# 2069.721781 is the largest absolute weight in the embedding
# json_stats: {"epoch": 274, "elapsed": 0.7564453429949936, "loss": 0.3245352640227528, }
# 2069.732689 is the largest absolute weight in the embedding
# json_stats: {"epoch": 275, "elapsed": 0.7348125120042823, "loss": 0.3170591115112342, }
# 2069.734096 is the largest absolute weight in the embedding
# json_stats: {"epoch": 276, "elapsed": 0.7539998749998631, "loss": 0.3112373492767891, }
# 2069.740218 is the largest absolute weight in the embedding
# json_stats: {"epoch": 277, "elapsed": 0.7858788739977172, "loss": 0.29522541536208374, }
# 2069.747127 is the largest absolute weight in the embedding
# json_stats: {"epoch": 278, "elapsed": 0.7342582679993939, "loss": 0.32390333619358913, }
# 2069.747215 is the largest absolute weight in the embedding
# json_stats: {"epoch": 279, "elapsed": 0.7126231210058904, "loss": 0.31348386810494167, }
# 2069.750373 is the largest absolute weight in the embedding
# json_stats: {"epoch": 280, "elapsed": 0.7418444420036394, "loss": 0.3150761966412263, }
# 2069.758627 is the largest absolute weight in the embedding
# json_stats: {"epoch": 281, "elapsed": 0.7393839840005967, "loss": 0.30550928382147835, }
# 2069.760254 is the largest absolute weight in the embedding
# json_stats: {"epoch": 282, "elapsed": 0.7076567600015551, "loss": 0.3010599697286426, }
# 2069.754791 is the largest absolute weight in the embedding
# json_stats: {"epoch": 283, "elapsed": 0.7246618239951204, "loss": 0.3061350462466824, }
# 2069.765555 is the largest absolute weight in the embedding
# json_stats: {"epoch": 284, "elapsed": 0.7132982010007254, "loss": 0.29368313268661816, }
# 2069.766128 is the largest absolute weight in the embedding
# json_stats: {"epoch": 285, "elapsed": 0.7508984660016722, "loss": 0.3147648147091477, }
# 2069.775187 is the largest absolute weight in the embedding
# json_stats: {"epoch": 286, "elapsed": 0.7366260759954457, "loss": 0.29933023797796926, }
# 2069.777678 is the largest absolute weight in the embedding
# json_stats: {"epoch": 287, "elapsed": 0.721320871001808, "loss": 0.2952926571963698, }
# 2069.782782 is the largest absolute weight in the embedding
# json_stats: {"epoch": 288, "elapsed": 0.7194762720027938, "loss": 0.2934837275311718, }
# 2069.798251 is the largest absolute weight in the embedding
# json_stats: {"epoch": 289, "elapsed": 0.7204332460023579, "loss": 0.28729756614504526, }
# 2069.798613 is the largest absolute weight in the embedding
# json_stats: {"epoch": 290, "elapsed": 0.7240509240000392, "loss": 0.29508021339040136, }
# 2069.81317 is the largest absolute weight in the embedding
# json_stats: {"epoch": 291, "elapsed": 0.729717324997182, "loss": 0.2868989877076548, }
# 2069.820333 is the largest absolute weight in the embedding
# json_stats: {"epoch": 292, "elapsed": 0.7866699139995035, "loss": 0.2930637006466363, }
# 2069.822472 is the largest absolute weight in the embedding
# json_stats: {"epoch": 293, "elapsed": 0.7662580219985102, "loss": 0.2713096649607419, }
# 2069.826382 is the largest absolute weight in the embedding
# json_stats: {"epoch": 294, "elapsed": 0.7510974459946738, "loss": 0.2836832929684814, }
# 2069.827139 is the largest absolute weight in the embedding
# json_stats: {"epoch": 295, "elapsed": 0.7596516810008325, "loss": 0.28412954030454035, }
# 2069.827007 is the largest absolute weight in the embedding
# json_stats: {"epoch": 296, "elapsed": 0.773606511997059, "loss": 0.2799968171034127, }
# 2069.826034 is the largest absolute weight in the embedding
# json_stats: {"epoch": 297, "elapsed": 0.7452072649975889, "loss": 0.27569107112300306, }
# 2069.845785 is the largest absolute weight in the embedding
# json_stats: {"epoch": 298, "elapsed": 0.7450323850061977, "loss": 0.2758725413280863, }
# 2069.849115 is the largest absolute weight in the embedding
# json_stats: {"epoch": 299, "elapsed": 0.722043540001323, "loss": 0.2736001098031968, }
# 2069.85161 is the largest absolute weight in the embedding
# json_stats: {"epoch": 300, "elapsed": 0.7550120749947382, "loss": 0.27955175559176065, }
# 2069.858137 is the largest absolute weight in the embedding
# json_stats: {"epoch": 301, "elapsed": 0.7336748270026874, "loss": 0.27252900196365193, }
# 2069.859274 is the largest absolute weight in the embedding
# json_stats: {"epoch": 302, "elapsed": 0.7653413330044714, "loss": 0.2603102335470455, }
# 2069.859156 is the largest absolute weight in the embedding
# json_stats: {"epoch": 303, "elapsed": 0.726430993003305, "loss": 0.26428637236391106, }
# 2069.862958 is the largest absolute weight in the embedding
# json_stats: {"epoch": 304, "elapsed": 0.730781999998726, "loss": 0.27110136158087, }
# 2069.862839 is the largest absolute weight in the embedding
# json_stats: {"epoch": 305, "elapsed": 0.7294110250004451, "loss": 0.2629110051803824, }
# 2069.864882 is the largest absolute weight in the embedding
# json_stats: {"epoch": 306, "elapsed": 0.7260805780024384, "loss": 0.25510952821909866, }
# 2069.865402 is the largest absolute weight in the embedding
# json_stats: {"epoch": 307, "elapsed": 0.7243120490020374, "loss": 0.25922818499758904, }
# 2069.870197 is the largest absolute weight in the embedding
# json_stats: {"epoch": 308, "elapsed": 0.7223602450030739, "loss": 0.26455173894923845, }
# 2069.87333 is the largest absolute weight in the embedding
# json_stats: {"epoch": 309, "elapsed": 0.7142115259994171, "loss": 0.2634923206323196, }
# 2069.875738 is the largest absolute weight in the embedding
# json_stats: {"epoch": 310, "elapsed": 0.7162838889998966, "loss": 0.25285831740389747, }
# 2069.877762 is the largest absolute weight in the embedding
# json_stats: {"epoch": 311, "elapsed": 0.7175294340049732, "loss": 0.2585507236092946, }
# 2069.883985 is the largest absolute weight in the embedding
# json_stats: {"epoch": 312, "elapsed": 0.7069664839946199, "loss": 0.26263566270903566, }
# 2069.885556 is the largest absolute weight in the embedding
# json_stats: {"epoch": 313, "elapsed": 0.7133750260036322, "loss": 0.25638179715936255, }
# 2069.891162 is the largest absolute weight in the embedding
# json_stats: {"epoch": 314, "elapsed": 0.730824994003342, "loss": 0.2601399520893811, }
# 2069.889843 is the largest absolute weight in the embedding
# json_stats: {"epoch": 315, "elapsed": 0.7242218739993405, "loss": 0.2421944998779226, }
# 2069.890706 is the largest absolute weight in the embedding
# json_stats: {"epoch": 316, "elapsed": 0.7528542509971885, "loss": 0.25153660237995695, }
# 2069.892514 is the largest absolute weight in the embedding
# json_stats: {"epoch": 317, "elapsed": 0.7425583980002557, "loss": 0.2694924859624182, }
# 2069.893447 is the largest absolute weight in the embedding
# json_stats: {"epoch": 318, "elapsed": 0.7361940760019934, "loss": 0.2561885717601453, }
# 2069.893885 is the largest absolute weight in the embedding
# json_stats: {"epoch": 319, "elapsed": 0.7457424550011638, "loss": 0.2452230315657445, }
# 2069.894357 is the largest absolute weight in the embedding
# json_stats: {"epoch": 320, "elapsed": 0.7307699500015588, "loss": 0.2487953722637098, }
# 2069.897343 is the largest absolute weight in the embedding
# json_stats: {"epoch": 321, "elapsed": 0.7335051570044016, "loss": 0.2486011871237691, }
# 2069.898216 is the largest absolute weight in the embedding
# json_stats: {"epoch": 322, "elapsed": 0.7299879699930898, "loss": 0.2482765477169274, }
# 2069.899232 is the largest absolute weight in the embedding
# json_stats: {"epoch": 323, "elapsed": 0.7416617229973781, "loss": 0.24039684294408117, }
# 2069.899942 is the largest absolute weight in the embedding
# json_stats: {"epoch": 324, "elapsed": 0.7204716210035258, "loss": 0.23887684329360936, }
# 2069.903445 is the largest absolute weight in the embedding
# json_stats: {"epoch": 325, "elapsed": 0.7226348699987284, "loss": 0.24643465122598646, }
# 2069.90341 is the largest absolute weight in the embedding
# ...
# 2069.975038 is the largest absolute weight in the embedding
# json_stats: {"epoch": 893, "elapsed": 0.7560628630017163, "loss": 0.11075264393176018, }
# 2069.975039 is the largest absolute weight in the embedding
# json_stats: {"epoch": 894, "elapsed": 0.7555873029996292, "loss": 0.11337537492494329, }
# 2069.975039 is the largest absolute weight in the embedding
# json_stats: {"epoch": 895, "elapsed": 0.7761500850028824, "loss": 0.10144613862187365, }
# 2069.975039 is the largest absolute weight in the embedding
# json_stats: {"epoch": 896, "elapsed": 0.7237215889981599, "loss": 0.11101318030177236, }
# 2069.975039 is the largest absolute weight in the embedding
# json_stats: {"epoch": 897, "elapsed": 0.7175905230033095, "loss": 0.1099126409048949, }
# 2069.975045 is the largest absolute weight in the embedding
# json_stats: {"epoch": 898, "elapsed": 0.7319729640003061, "loss": 0.11619060335480796, }
# 2069.975046 is the largest absolute weight in the embedding
# json_stats: {"epoch": 899, "elapsed": 0.7126116060026106, "loss": 0.1046184758621809, }
# 2069.975044 is the largest absolute weight in the embedding
# json_stats: {"epoch": 900, "elapsed": 0.7108626869958243, "loss": 0.10643727281973181, }
# 2069.975044 is the largest absolute weight in the embedding
# json_stats: {"epoch": 901, "elapsed": 0.7254396280040964, "loss": 0.10731040780145616, }
# 2069.975045 is the largest absolute weight in the embedding
# json_stats: {"epoch": 902, "elapsed": 0.7181860519995098, "loss": 0.11318585591611198, }
# 2069.975044 is the largest absolute weight in the embedding
# json_stats: {"epoch": 903, "elapsed": 0.7117836160032311, "loss": 0.11635773372054045, }
# 2069.975045 is the largest absolute weight in the embedding
# json_stats: {"epoch": 904, "elapsed": 0.7266016979992855, "loss": 0.11087954578007819, }
# 2069.975046 is the largest absolute weight in the embedding
# json_stats: {"epoch": 905, "elapsed": 0.7139272210042691, "loss": 0.10804595907182128, }
# 2069.975047 is the largest absolute weight in the embedding
# json_stats: {"epoch": 906, "elapsed": 0.7236258289995021, "loss": 0.11143844425584377, }
# 2069.975049 is the largest absolute weight in the embedding
# json_stats: {"epoch": 907, "elapsed": 0.7287041059971671, "loss": 0.1097927086347494, }
# 2069.975055 is the largest absolute weight in the embedding
# json_stats: {"epoch": 908, "elapsed": 0.7140401500000735, "loss": 0.1051770943752875, }
# 2069.975056 is the largest absolute weight in the embedding
# json_stats: {"epoch": 909, "elapsed": 0.7413608179995208, "loss": 0.10898970157011646, }
# 2069.975054 is the largest absolute weight in the embedding
# json_stats: {"epoch": 910, "elapsed": 0.7065580349953962, "loss": 0.11200658816611998, }
# 2069.975056 is the largest absolute weight in the embedding
# json_stats: {"epoch": 911, "elapsed": 0.7181173779972596, "loss": 0.10380859915258488, }
# 2069.975059 is the largest absolute weight in the embedding
# json_stats: {"epoch": 912, "elapsed": 0.7858361340040574, "loss": 0.10332677241378396, }
# 2069.975062 is the largest absolute weight in the embedding
# json_stats: {"epoch": 913, "elapsed": 0.7514212909954949, "loss": 0.10776181299668884, }
# 2069.975064 is the largest absolute weight in the embedding
# json_stats: {"epoch": 914, "elapsed": 0.7702345040015643, "loss": 0.10516860271928118, }
# 2069.975065 is the largest absolute weight in the embedding
# json_stats: {"epoch": 915, "elapsed": 0.7234290350024821, "loss": 0.11394811276308392, }
# 2069.975067 is the largest absolute weight in the embedding
# json_stats: {"epoch": 916, "elapsed": 0.7586831869994057, "loss": 0.10491891951581797, }
# 2069.975071 is the largest absolute weight in the embedding
# json_stats: {"epoch": 917, "elapsed": 0.7303209050005535, "loss": 0.11028841034798886, }
# 2069.975075 is the largest absolute weight in the embedding
# json_stats: {"epoch": 918, "elapsed": 0.7181408280011965, "loss": 0.11654200080742645, }
# 2069.975074 is the largest absolute weight in the embedding
# json_stats: {"epoch": 919, "elapsed": 0.7678427459977684, "loss": 0.11540408768299874, }
# 2069.975078 is the largest absolute weight in the embedding
# json_stats: {"epoch": 920, "elapsed": 0.7673314170024241, "loss": 0.10569703972771602, }
# 2069.975079 is the largest absolute weight in the embedding
# json_stats: {"epoch": 921, "elapsed": 0.7486998280000989, "loss": 0.10549304374398687, }
# 2069.97508 is the largest absolute weight in the embedding
# json_stats: {"epoch": 922, "elapsed": 0.773602856999787, "loss": 0.10474562660350299, }
# 2069.97508 is the largest absolute weight in the embedding
# json_stats: {"epoch": 923, "elapsed": 0.7591669260000344, "loss": 0.10408518676017854, }
# 2069.975081 is the largest absolute weight in the embedding
# json_stats: {"epoch": 924, "elapsed": 0.7358436209979118, "loss": 0.11215087776134217, }
# 2069.975081 is the largest absolute weight in the embedding
# json_stats: {"epoch": 925, "elapsed": 0.7145720850021462, "loss": 0.10242644267226106, }
# 2069.975082 is the largest absolute weight in the embedding
# json_stats: {"epoch": 926, "elapsed": 0.7098531019946677, "loss": 0.11263581391518682, }
# 2069.975082 is the largest absolute weight in the embedding
# json_stats: {"epoch": 927, "elapsed": 0.7250889539936907, "loss": 0.10239077867201592, }
# 2069.975083 is the largest absolute weight in the embedding
# json_stats: {"epoch": 928, "elapsed": 0.7090397140054847, "loss": 0.10554149526315099, }
# 2069.975083 is the largest absolute weight in the embedding
# json_stats: {"epoch": 929, "elapsed": 0.7098990890008281, "loss": 0.10612286973899256, }
# 2069.975086 is the largest absolute weight in the embedding
# json_stats: {"epoch": 930, "elapsed": 0.7298969000039506, "loss": 0.10372527985882438, }
# 2069.975086 is the largest absolute weight in the embedding
# json_stats: {"epoch": 931, "elapsed": 0.7231810789962765, "loss": 0.11019192737609274, }
# 2069.975087 is the largest absolute weight in the embedding
# json_stats: {"epoch": 932, "elapsed": 0.7219920399948023, "loss": 0.1047965327796245, }
# 2069.975087 is the largest absolute weight in the embedding
# json_stats: {"epoch": 933, "elapsed": 0.7242015439987881, "loss": 0.11062271996297426, }
# 2069.975087 is the largest absolute weight in the embedding
# json_stats: {"epoch": 934, "elapsed": 0.7185048269966501, "loss": 0.10549996761799371, }
# 2069.97509 is the largest absolute weight in the embedding
# json_stats: {"epoch": 935, "elapsed": 0.7217896899965126, "loss": 0.10452695564289964, }
# 2069.97509 is the largest absolute weight in the embedding
# json_stats: {"epoch": 936, "elapsed": 0.7175419729974237, "loss": 0.10209903629728102, }
# 2069.975092 is the largest absolute weight in the embedding
# json_stats: {"epoch": 937, "elapsed": 0.7175608379984624, "loss": 0.10525430992655517, }
# 2069.975092 is the largest absolute weight in the embedding
# json_stats: {"epoch": 938, "elapsed": 0.7394265129987616, "loss": 0.10293699211702183, }
# 2069.975093 is the largest absolute weight in the embedding
# json_stats: {"epoch": 939, "elapsed": 0.7543689939993783, "loss": 0.1075459326041851, }
# 2069.975091 is the largest absolute weight in the embedding
# json_stats: {"epoch": 940, "elapsed": 0.7272773719960242, "loss": 0.11068237712923844, }
# 2069.975092 is the largest absolute weight in the embedding
# json_stats: {"epoch": 941, "elapsed": 0.7196596119974856, "loss": 0.10958027041070506, }
# 2069.975094 is the largest absolute weight in the embedding
# json_stats: {"epoch": 942, "elapsed": 0.7540103749997797, "loss": 0.10441017862934757, }
# 2069.975095 is the largest absolute weight in the embedding
# json_stats: {"epoch": 943, "elapsed": 0.7261202930021682, "loss": 0.10231920280210335, }
# 2069.975093 is the largest absolute weight in the embedding
# json_stats: {"epoch": 944, "elapsed": 0.7268338459980441, "loss": 0.10847539217923173, }
# 2069.975096 is the largest absolute weight in the embedding
# json_stats: {"epoch": 945, "elapsed": 0.7271993069953169, "loss": 0.10488260318823468, }
# 2069.975096 is the largest absolute weight in the embedding
# json_stats: {"epoch": 946, "elapsed": 0.7088036040004226, "loss": 0.10735827470437755, }
# 2069.975096 is the largest absolute weight in the embedding
# json_stats: {"epoch": 947, "elapsed": 0.7214673910057172, "loss": 0.10232518109653364, }
# 2069.975097 is the largest absolute weight in the embedding
# json_stats: {"epoch": 948, "elapsed": 0.7342565880026086, "loss": 0.10523500427062535, }
# 2069.975098 is the largest absolute weight in the embedding
# json_stats: {"epoch": 949, "elapsed": 0.7082817100017564, "loss": 0.11553261178769055, }
# 2069.9751 is the largest absolute weight in the embedding
# json_stats: {"epoch": 950, "elapsed": 0.7149870799985365, "loss": 0.1044830824833292, }
# 2069.975101 is the largest absolute weight in the embedding
# json_stats: {"epoch": 951, "elapsed": 0.7337920729987673, "loss": 0.10029039036117697, }
# 2069.975104 is the largest absolute weight in the embedding
# json_stats: {"epoch": 952, "elapsed": 0.719179637999332, "loss": 0.10072975624498635, }
# 2069.975104 is the largest absolute weight in the embedding
# json_stats: {"epoch": 953, "elapsed": 0.7136102559961728, "loss": 0.1065501357663347, }
# 2069.975106 is the largest absolute weight in the embedding
# json_stats: {"epoch": 954, "elapsed": 0.724944333996973, "loss": 0.10985677601168477, }
# 2069.975111 is the largest absolute weight in the embedding
# json_stats: {"epoch": 955, "elapsed": 0.7299153599960846, "loss": 0.10362563173653216, }
# 2069.975111 is the largest absolute weight in the embedding
# json_stats: {"epoch": 956, "elapsed": 0.7024792279989924, "loss": 0.10177947486295547, }
# 2069.975114 is the largest absolute weight in the embedding
# json_stats: {"epoch": 957, "elapsed": 0.7394249839999247, "loss": 0.10989102158198935, }
# 2069.975116 is the largest absolute weight in the embedding
# json_stats: {"epoch": 958, "elapsed": 0.7174067879968788, "loss": 0.10312023817161675, }
# 2069.975119 is the largest absolute weight in the embedding
# json_stats: {"epoch": 959, "elapsed": 0.7194525770028122, "loss": 0.11415328614327108, }
# 2069.97512 is the largest absolute weight in the embedding
# json_stats: {"epoch": 960, "elapsed": 0.7201270060031675, "loss": 0.10782996118538858, }
# 2069.97512 is the largest absolute weight in the embedding
# json_stats: {"epoch": 961, "elapsed": 0.7243796629991266, "loss": 0.10316026269507358, }
# 2069.975121 is the largest absolute weight in the embedding
# json_stats: {"epoch": 962, "elapsed": 0.7269896470024833, "loss": 0.10581214439355335, }
# 2069.975124 is the largest absolute weight in the embedding
# json_stats: {"epoch": 963, "elapsed": 0.7285534809998353, "loss": 0.10805158433039885, }
# 2069.975124 is the largest absolute weight in the embedding
# json_stats: {"epoch": 964, "elapsed": 0.7172662790035247, "loss": 0.10766263127964688, }
# 2069.975123 is the largest absolute weight in the embedding
# json_stats: {"epoch": 965, "elapsed": 0.7165195240013418, "loss": 0.10299629669081714, }
# 2069.975123 is the largest absolute weight in the embedding
# json_stats: {"epoch": 966, "elapsed": 0.7208524060042691, "loss": 0.10754132158039789, }
# 2069.975124 is the largest absolute weight in the embedding
# json_stats: {"epoch": 967, "elapsed": 0.7171467499938444, "loss": 0.10670646065107459, }
# 2069.975125 is the largest absolute weight in the embedding
# json_stats: {"epoch": 968, "elapsed": 0.7105547180035501, "loss": 0.09809300972476087, }
# 2069.975128 is the largest absolute weight in the embedding
# json_stats: {"epoch": 969, "elapsed": 0.7162523790029809, "loss": 0.10805555503250062, }
# 2069.975133 is the largest absolute weight in the embedding
# json_stats: {"epoch": 970, "elapsed": 0.7066360600001644, "loss": 0.10543080707867246, }
# 2069.975133 is the largest absolute weight in the embedding
# json_stats: {"epoch": 971, "elapsed": 0.7224900799992611, "loss": 0.10696311991349411, }
# 2069.975134 is the largest absolute weight in the embedding
# json_stats: {"epoch": 972, "elapsed": 0.7205875409999862, "loss": 0.10394567639160876, }
# 2069.975136 is the largest absolute weight in the embedding
# json_stats: {"epoch": 973, "elapsed": 0.7138220099950559, "loss": 0.10765992530490807, }
# 2069.975136 is the largest absolute weight in the embedding
# json_stats: {"epoch": 974, "elapsed": 0.7184533119943808, "loss": 0.10968472534607598, }
# 2069.975136 is the largest absolute weight in the embedding
# json_stats: {"epoch": 975, "elapsed": 0.717025508005463, "loss": 0.10763046969297915, }
# 2069.975138 is the largest absolute weight in the embedding
# json_stats: {"epoch": 976, "elapsed": 0.7106265229958808, "loss": 0.10276081532608665, }
# 2069.97514 is the largest absolute weight in the embedding
# json_stats: {"epoch": 977, "elapsed": 0.7069645449955715, "loss": 0.10967946872902869, }
# 2069.975143 is the largest absolute weight in the embedding
# json_stats: {"epoch": 978, "elapsed": 0.7217453549965285, "loss": 0.10555274383376594, }
# 2069.975144 is the largest absolute weight in the embedding
# json_stats: {"epoch": 979, "elapsed": 0.7152832749998197, "loss": 0.10054252619422725, }
# 2069.975145 is the largest absolute weight in the embedding
# json_stats: {"epoch": 980, "elapsed": 0.7245721979998052, "loss": 0.09947909160141849, }
# 2069.975147 is the largest absolute weight in the embedding
# json_stats: {"epoch": 981, "elapsed": 0.7107401319954079, "loss": 0.10798656196988266, }
# 2069.975147 is the largest absolute weight in the embedding
# json_stats: {"epoch": 982, "elapsed": 0.7070386049963417, "loss": 0.10477332977720182, }
# 2069.975148 is the largest absolute weight in the embedding
# json_stats: {"epoch": 983, "elapsed": 0.768284030003997, "loss": 0.10556596548552524, }
# 2069.975148 is the largest absolute weight in the embedding
# json_stats: {"epoch": 984, "elapsed": 0.7324488680023933, "loss": 0.10872237098773876, }
# 2069.975151 is the largest absolute weight in the embedding
# json_stats: {"epoch": 985, "elapsed": 0.7334926729963627, "loss": 0.1031952183259523, }
# 2069.975151 is the largest absolute weight in the embedding
# json_stats: {"epoch": 986, "elapsed": 0.7074535299980198, "loss": 0.10626788780122551, }
# 2069.975151 is the largest absolute weight in the embedding
# json_stats: {"epoch": 987, "elapsed": 0.7203662469983101, "loss": 0.10179901923705272, }
# 2069.975151 is the largest absolute weight in the embedding
# json_stats: {"epoch": 988, "elapsed": 0.7165660790051334, "loss": 0.10009112208898886, }
# 2069.975153 is the largest absolute weight in the embedding
# json_stats: {"epoch": 989, "elapsed": 0.7260606620038743, "loss": 0.10645492214779718, }
# 2069.975153 is the largest absolute weight in the embedding
# json_stats: {"epoch": 990, "elapsed": 0.7155293489995529, "loss": 0.10637981459178264, }
# 2069.975154 is the largest absolute weight in the embedding
# json_stats: {"epoch": 991, "elapsed": 0.7211487400054466, "loss": 0.10323000916150654, }
# 2069.975155 is the largest absolute weight in the embedding
# json_stats: {"epoch": 992, "elapsed": 0.7455060399952345, "loss": 0.10210420074224186, }
# 2069.975155 is the largest absolute weight in the embedding
# json_stats: {"epoch": 993, "elapsed": 0.7357302020027419, "loss": 0.10477130382585277, }
# 2069.975154 is the largest absolute weight in the embedding
# json_stats: {"epoch": 994, "elapsed": 0.7133190009990358, "loss": 0.10198640612904934, }
# 2069.975153 is the largest absolute weight in the embedding
# json_stats: {"epoch": 995, "elapsed": 0.7587859120030771, "loss": 0.10602392411636519, }
# 2069.975154 is the largest absolute weight in the embedding
# json_stats: {"epoch": 996, "elapsed": 0.7187140379974153, "loss": 0.10227848954920127, }
# 2069.975154 is the largest absolute weight in the embedding
# json_stats: {"epoch": 997, "elapsed": 0.7267600419945666, "loss": 0.10100639319747182, }
# 2069.975156 is the largest absolute weight in the embedding
# json_stats: {"epoch": 998, "elapsed": 0.7629500990005909, "loss": 0.10492824517287165, }
# 2069.975156 is the largest absolute weight in the embedding
# json_stats: {"epoch": 999, "elapsed": 0.7208778159983922, "loss": 0.10261301962844345, }
# Total training time is: 729.8673656419996

# %% [markdown]
# # Evaluate embedding

# %%
meanrank, maprank = eval_reconstruction(
    adj, model.lt.weight.data.clone(), manifold.distance, workers=opt_ndproc)
sqnorms = manifold.pnorm(model.lt.weight.data.clone())
log.info(
        'json_stats final test: \n{' 
        f'"sqnorm_min": {round(sqnorms.min().item(),6)}, '
        f'"sqnorm_avg": {round(sqnorms.mean().item(),6)}, '
        f'"sqnorm_max": {round(sqnorms.max().item(),6)}, \n'
        f'"mean_rank": {round(meanrank,6)}, '
        f'"map": {round(maprank,6)}, '
        '}'
    )
print(model.lt.weight.data[0])
# Out:
# json_stats final test:
# {"sqnorm_min": 0.44194, "sqnorm_avg": 0.998845, "sqnorm_max": 1.0,
# "mean_rank": 1.790061, "map": 0.880847, }
# tensor([-1.7542e-01,  1.0284e-07])
